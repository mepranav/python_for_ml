# %%
import seaborn as sns

# %%
my_data=sns.load_dataset("iris")
my_data.shape
my_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
my_data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
my_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
my_data = sns.load_dataset("iris")
sns.jointplot(x="sepal_length",y="sepal_width",data=my_data)

# %%
my_data = sns.load_dataset("iris")
sns.jointplot(x="species",y="sepal_length",data=my_data)

# %%
my_data = sns.load_dataset("iris")
sns.stripplot(x="sepal_length",y="sepal_width",data=my_data)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.pairplot(my_data)

# %%
sns.pairplot(my_data,hue="species")

# %%
sns.pairplot(my_data , hue = "species",markers=["o", "s", "D"])

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
colormap = np.array(['red', 'lime', 'black'])
plt.scatter(my_data.sepal_length,my_data.sepal_width,s=40)
plt.title('Sepal')
# Out:
# Text(0.5, 1.0, 'Sepal')

# %%
my_data['sepal_length'].value_counts().plot.bar()
plt.title('Sepal')
# Out:
# Text(0.5, 1.0, 'Sepal')

# %%
my_data['sepal_length'].plot.hist()
plt.title('Sepal')
# Out:
# Text(0.5, 1.0, 'Sepal')
